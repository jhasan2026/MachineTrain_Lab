# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../Data/top100_ai_tools_2026.csv")
df
# Out:
#      Rank     Tool_Name   Primary_Category         Sub_Category Pricing_Model  \
# 0       1       ChatGPT  Conversational AI    General Assistant      Freemium
# 1       2        Gemini  Conversational AI        Multimodal AI      Freemium
# 2       3      Canva AI   Image Generation     Design Assistant      Freemium
# 3       4  Character.AI  Conversational AI      Roleplay & Chat      Freemium
# 4       5        Claude  Conversational AI    General Assistant      Freemium
# ..    ...           ...                ...                  ...           ...
# 495   496     Koral Bot  Research & Search      Market Research          Paid
# 496   497    Quill Flow    HR & Recruiting  Employee Onboarding          Paid
# 497   498    Cipher GPT           Legal AI       Legal Research          Paid
# 498   499     Quill GPT    HR & Recruiting  Employee Onboarding          Paid
# 499   500   Cipher Flow   Cybersecurity AI     Threat Detection          Paid
#
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Tool_Name', 'Primary_Category', 'Sub_Category',
#        'Pricing_Model', 'Starting_Price_USD', 'Monthly_Traffic_Est',
#        'User_Rating', 'Agentic_Capability_Score', 'API_Available',
#        'Release_Year', 'Active_Users_Est', 'Description'],
#       dtype='str')

# %%
num = ['Starting_Price_USD', 'Monthly_Traffic_Est', 'User_Rating', 'Agentic_Capability_Score', 'Active_Users_Est']

cat = ['Primary_Category','Pricing_Model', 'API_Available', 'Release_Year']

# %%
df['Pricing_Model'].value_counts()
# Out:
# Pricing_Model
# Paid           252
# Freemium       207
# Free            24
# Pay-per-use     16
# API/Paid         1
# Name: count, dtype: int64

# %%
df['Pricing_Model'].value_counts()
# Out:
# Pricing_Model
# Paid           252
# Freemium       207
# Free            24
# Pay-per-use     16
# API/Paid         1
# Name: count, dtype: int64

# %% [markdown]
# # 1. Numerical

# %% [markdown]
# ## 1.1 Histplot
#
#   ⬆️ count
#   ---------- ➡️ num

# %%
sns.displot(kind='hist', data=df, x='Starting_Price_USD',hue='Pricing_Model')

# %%
for col in num:
    sns.displot(kind='hist', data=df, x=col)

# %% [markdown]
# ## 1.2 KdePlot
#
#   ⬆️ density
#   ---------- ➡️ num

# %%
sns.displot(kind='kde', data=df, x="Starting_Price_USD", hue="API_Available")

# %%
sns.displot(kind='kde', data=df, x="Starting_Price_USD", hue="API_Available")
sns.rugplot( data=df, x="Starting_Price_USD")
# Out:
# <Axes: xlabel='Starting_Price_USD', ylabel='Density'>

# %%
for col in num:
    sns.displot(kind='kde', data=df, x=col)

# %% [markdown]
# ### 1.3 Boxplot

# %%
sns.catplot(kind='box',data=df,x='Starting_Price_USD',hue='API_Available')

# %%
for col in num:
    sns.catplot(kind='box',data=df,x=col)

# %% [markdown]
# # 2. Categorical
#
# ## 2.1 Count Plot

# %%
sns.catplot(kind='count', data=df, x="Pricing_Model", hue="API_Available")

# %%
for col in cat:
    g = sns.catplot(kind='count', data=df, x=col)
    g.set_xticklabels(rotation=90)

# %% [markdown]
# ## 2.2 Pie Chart

# %%
plt.figure(figsize=(12,12))
df['Pricing_Model'].value_counts().plot(kind='pie', autopct="%.2f")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,12))
df['Primary_Category'].value_counts().plot(kind='pie', autopct="%.2f")
# Out:
# <Axes: >
