# %%
import pandas as pd

# %%
df = pd.read_csv("../../Data/top100_ai_tools_2026.csv")
df
# Out:
#      Rank     Tool_Name   Primary_Category         Sub_Category Pricing_Model  \
# 0       1       ChatGPT  Conversational AI    General Assistant      Freemium
# 1       2        Gemini  Conversational AI        Multimodal AI      Freemium
# 2       3      Canva AI   Image Generation     Design Assistant      Freemium
# 3       4  Character.AI  Conversational AI      Roleplay & Chat      Freemium
# 4       5        Claude  Conversational AI    General Assistant      Freemium
# ..    ...           ...                ...                  ...           ...
# 495   496     Koral Bot  Research & Search      Market Research          Paid
# 496   497    Quill Flow    HR & Recruiting  Employee Onboarding          Paid
# 497   498    Cipher GPT           Legal AI       Legal Research          Paid
# 498   499     Quill GPT    HR & Recruiting  Employee Onboarding          Paid
# 499   500   Cipher Flow   Cybersecurity AI     Threat Detection          Paid
#
# ...

# %% [markdown]
# # 1. How big data is?

# %%
df.shape
# Out:
# (500, 13)

# %% [markdown]
# # 2. Data looks like

# %%
df.sample(10)
# Out:
#      Rank     Tool_Name  Primary_Category        Sub_Category Pricing_Model  \
# 172   173       Durable       Web Builder    Website Creation          Paid
# 437   438    Arcane Lab        Automation            RPA + AI          Paid
# 184   185     Karma Pro  Video Generation        AI Thumbnail      Freemium
# 153   154   Neon Engine         Education     Homework Helper          Paid
# 497   498    Cipher GPT          Legal AI      Legal Research          Paid
# 441   442    Iris Suite     Healthcare AI     Medical Imaging          Paid
# 29     30       Jira AI      Productivity      Issue Tracking      Freemium
# 273   274    Cleanvoice     Audio & Voice       Audio Cleanup      Freemium
# 224   225  Lyric Vision   Developer Tools  Prompt Engineering          Paid
# 134   135     Linear AI      Productivity      Issue Tracking          Paid
#
#      Starting_Price_USD  Monthly_Traffic_Est  User_Rating  \
# 172               15.00              2000000         4.00
# ...

# %% [markdown]
# # 3. Data type of the columns

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      500 non-null    int64
#  1   Tool_Name                 500 non-null    str
#  2   Primary_Category          500 non-null    str
#  3   Sub_Category              500 non-null    str
#  4   Pricing_Model             500 non-null    str
#  5   Starting_Price_USD        500 non-null    float64
#  6   Monthly_Traffic_Est       500 non-null    int64
#  7   User_Rating               500 non-null    float64
#  8   Agentic_Capability_Score  500 non-null    float64
#  9   API_Available             500 non-null    str
#  10  Release_Year              500 non-null    int64
#  11  Active_Users_Est          500 non-null    int64
#  12  Description               500 non-null    str
# dtypes: float64(3), int64(4), str(6)
# memory usage: 50.9 KB

# %% [markdown]
# # 4. Missing Values

# %%
df.isnull().mean() * 100
# Out:
# Rank                        0.0
# Tool_Name                   0.0
# Primary_Category            0.0
# Sub_Category                0.0
# Pricing_Model               0.0
# Starting_Price_USD          0.0
# Monthly_Traffic_Est         0.0
# User_Rating                 0.0
# Agentic_Capability_Score    0.0
# API_Available               0.0
# Release_Year                0.0
# Active_Users_Est            0.0
# Description                 0.0
# dtype: float64

# %%
df.dropna(inplace=True)

# %% [markdown]
# # 5. all statistical information

# %%
df.describe()
# Out:
#              Rank  Starting_Price_USD  Monthly_Traffic_Est  User_Rating  \
# count  500.000000          500.000000         5.000000e+02   500.000000
# mean   250.500000           61.616940         1.189889e+07     4.285060
# std    144.481833           94.884544         8.868521e+07     0.171419
# min      1.000000            0.000000         6.587800e+04     3.800000
# 25%    125.750000           12.000000         6.152182e+05     4.157500
# 50%    250.500000           24.000000         1.148314e+06     4.290000
# 75%    375.250000           71.572500         3.000000e+06     4.400000
# max    500.000000         1000.000000         1.800000e+09     4.800000
#
#        Agentic_Capability_Score  Release_Year  Active_Users_Est
# count                500.000000    500.000000      5.000000e+02
# mean                   6.610580   2022.138000      1.948661e+06
# std                    1.494926      2.463146      1.246835e+07
# ...

# %% [markdown]
# # 6. Duplicate value check and remove

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
