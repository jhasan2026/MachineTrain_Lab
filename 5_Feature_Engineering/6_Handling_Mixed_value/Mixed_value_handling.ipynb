# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../Data/titanic_dum.csv")
df
# Out:
#     Cabin            Ticket number  Survived
# 0     NaN         A/5 21171      5         0
# 1     C85          PC 17599      3         1
# 2     NaN  STON/O2. 3101282      6         1
# 3    C123            113803      3         1
# 4     NaN            373450      A         0
# ..    ...               ...    ...       ...
# 886   NaN            211536      3         0
# 887   B42            112053      3         1
# 888   NaN        W./C. 6607      1         0
# 889  C148            111369      2         1
# 890   NaN            370376      3         0
#
# [891 rows x 4 columns]

# %%
df['number'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='number'>

# %% [markdown]
# # extract numerical part

# %%
df['number_numerical'] = pd.to_numeric(df['number'], errors='coerce',downcast='integer')
df
# Out:
#     Cabin            Ticket number  Survived  number_numerical
# 0     NaN         A/5 21171      5         0               5.0
# 1     C85          PC 17599      3         1               3.0
# 2     NaN  STON/O2. 3101282      6         1               6.0
# 3    C123            113803      3         1               3.0
# 4     NaN            373450      A         0               NaN
# ..    ...               ...    ...       ...               ...
# 886   NaN            211536      3         0               3.0
# 887   B42            112053      3         1               3.0
# 888   NaN        W./C. 6607      1         0               1.0
# 889  C148            111369      2         1               2.0
# 890   NaN            370376      3         0               3.0
#
# [891 rows x 5 columns]

# %% [markdown]
# # extract categorical part

# %%
df['number_categorical'] = np.where(
    df['number_numerical'].isnull(),
    df['number'],
    np.nan
)

# %%
df
# Out:
#     Cabin            Ticket number  Survived  number_numerical  \
# 0     NaN         A/5 21171      5         0               5.0
# 1     C85          PC 17599      3         1               3.0
# 2     NaN  STON/O2. 3101282      6         1               6.0
# 3    C123            113803      3         1               3.0
# 4     NaN            373450      A         0               NaN
# ..    ...               ...    ...       ...               ...
# 886   NaN            211536      3         0               3.0
# 887   B42            112053      3         1               3.0
# 888   NaN        W./C. 6607      1         0               1.0
# 889  C148            111369      2         1               2.0
# 890   NaN            370376      3         0               3.0
#
#     number_categorical
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                    A
# ..                 ...
# 886                NaN
# 887                NaN
# 888                NaN
# 889                NaN
# 890                NaN
#
# [891 rows x 6 columns]

# %% [markdown]
# # Cabin extract

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F33            3
# E101           3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df['Cabin_num'] = df['Cabin'].str.extract('(\d+)')
df['Cabin_cat'] = df['Cabin'].str[0]
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Jehan\AppData\Local\Temp\ipykernel_6396\2124599598.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['Cabin_num'] = df['Cabin'].str.extract('(\d+)')
#     Cabin            Ticket number  Survived  number_numerical  \
# 0     NaN         A/5 21171      5         0               5.0
# 1     C85          PC 17599      3         1               3.0
# 2     NaN  STON/O2. 3101282      6         1               6.0
# 3    C123            113803      3         1               3.0
# 4     NaN            373450      A         0               NaN
# ..    ...               ...    ...       ...               ...
# 886   NaN            211536      3         0               3.0
# 887   B42            112053      3         1               3.0
# 888   NaN        W./C. 6607      1         0               1.0
# 889  C148            111369      2         1               2.0
# 890   NaN            370376      3         0               3.0
#
#     number_categorical Cabin_num Cabin_cat
# 0                  NaN       NaN       NaN
# 1                  NaN        85         C
# 2                  NaN       NaN       NaN
# 3                  NaN       123         C
# 4                    A       NaN       NaN
# ..                 ...       ...       ...
# 886                NaN       NaN       NaN
# 887                NaN        42         B
# 888                NaN       NaN       NaN
# 889                NaN       148         C
# 890                NaN       NaN       NaN
#
# [891 rows x 8 columns]

# %% [markdown]
# # Extract ticket

# %%
df['Ticket_numerical'] = df['Ticket'].apply(lambda s: s.split()[-1])
df['Ticket_numerical'] = pd.to_numeric(df['Ticket_numerical'],errors='coerce',downcast='integer')
df
# Out:
#     Cabin            Ticket number  Survived  number_numerical  \
# 0     NaN         A/5 21171      5         0               5.0
# 1     C85          PC 17599      3         1               3.0
# 2     NaN  STON/O2. 3101282      6         1               6.0
# 3    C123            113803      3         1               3.0
# 4     NaN            373450      A         0               NaN
# ..    ...               ...    ...       ...               ...
# 886   NaN            211536      3         0               3.0
# 887   B42            112053      3         1               3.0
# 888   NaN        W./C. 6607      1         0               1.0
# 889  C148            111369      2         1               2.0
# 890   NaN            370376      3         0               3.0
#
#     number_categorical Cabin_num Cabin_cat  Ticket_numerical
# 0                  NaN       NaN       NaN           21171.0
# 1                  NaN        85         C           17599.0
# 2                  NaN       NaN       NaN         3101282.0
# 3                  NaN       123         C          113803.0
# 4                    A       NaN       NaN          373450.0
# ..                 ...       ...       ...               ...
# 886                NaN       NaN       NaN          211536.0
# 887                NaN        42         B          112053.0
# 888                NaN       NaN       NaN            6607.0
# 889                NaN       148         C          111369.0
# 890                NaN       NaN       NaN          370376.0
#
# [891 rows x 9 columns]
