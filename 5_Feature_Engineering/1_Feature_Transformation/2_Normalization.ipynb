# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../Data/wine_data.csv",usecols=[0,1,2], names=['Class_label',"Alcohol","Malic_acid"])
df
# Out:
#      Class_label  Alcohol  Malic_acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.displot(kind='kde', data=df, x='Alcohol')
sns.displot(kind='kde', data=df, x='Malic_acid')

# %%
sns.relplot(kind='scatter',data=df,x='Alcohol',y='Malic_acid',hue='Class_label')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['Class_label']), df['Class_label'],test_size=0.2, random_state=42)

# %%
X_train
# Out:
#      Alcohol  Malic_acid
# 158    14.34        1.68
# 137    12.53        5.51
# 98     12.37        1.07
# 159    13.48        1.67
# 38     13.07        1.50
# ..       ...         ...
# 71     13.86        1.51
# 106    12.25        1.73
# 14     14.38        1.87
# 92     12.69        1.53
# 102    12.34        2.45
#
# [142 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

X_train_scalled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scalled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
X_train.describe()
# Out:
#           Alcohol  Malic_acid
# count  142.000000  142.000000
# mean    12.979085    2.373521
# std      0.820116    1.143934
# min     11.030000    0.890000
# 25%     12.332500    1.615000
# 50%     13.010000    1.875000
# 75%     13.677500    3.135000
# max     14.830000    5.800000

# %%
X_train_scalled.describe()
# Out:
#           Alcohol  Malic_acid
# count  142.000000  142.000000
# mean     0.512917    0.302143
# std      0.215820    0.232980
# min      0.000000    0.000000
# 25%      0.342763    0.147658
# 50%      0.521053    0.200611
# 75%      0.696711    0.457230
# max      1.000000    1.000000

# %%
sns.relplot(kind='scatter',data=X_train,x='Alcohol',y='Malic_acid')
sns.relplot(kind='scatter',data=X_train_scalled,x='Alcohol',y='Malic_acid')
